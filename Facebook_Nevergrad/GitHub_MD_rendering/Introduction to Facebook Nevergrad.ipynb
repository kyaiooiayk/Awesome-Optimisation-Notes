# %% [markdown]
# # Introduction

# %% [markdown]
# **What?** Introduction to Facebook Nevergrad

# %% [markdown]
# # Import modules

# %%
import nevergrad as ng
import numpy as np

# Getting rid of the warning messages
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Explore the available optimiser

# %%
for OPTIMISER in sorted(ng.optimizers.registry.keys()):
    print(OPTIMISER)
# Out:
# ASCMADEthird
# AdaptiveDiscreteOnePlusOne
# AlmostRotationInvariantDE
# AnisotropicAdaptiveDiscreteOnePlusOne
# AvgMetaRecenteringNoHull
# BO
# BOSplit
# BayesOptimBO
# CM
# CMA
# CMandAS2
# CMandAS3
# CauchyLHSSearch
# CauchyOnePlusOne
# CauchyScrHammersleySearch
# ChainCMAPowell
# ChainDiagonalCMAPowell
# ChainMetaModelPowell
# ChainMetaModelSQP
# ChainNaiveTBPSACMAPowell
# ChainNaiveTBPSAPowell
# Cobyla
# DE
# DiagonalCMA
# DiscreteBSOOnePlusOne
# DiscreteDoerrOnePlusOne
# DiscreteLenglerOnePlusOne
# DiscreteOnePlusOne
# DoubleFastGADiscreteOnePlusOne
# EDA
# ES
# FCMA
# GeneticDE
# HaltonSearch
# HaltonSearchPlusMiddlePoint
# HammersleySearch
# HammersleySearchPlusMiddlePoint
# HullAvgMetaRecentering
# HullAvgMetaTuneRecentering
# LHSSearch
# LargeHaltonSearch
# LhsDE
# MetaModel
# MetaRecentering
# MetaTuneRecentering
# MixES
# MultiCMA
# MultiDiscrete
# MultiScaleCMA
# MutDE
# NGO
# NGOpt
# NGOpt10
# NGOpt12
# NGOpt13
# NGOpt14
# NGOpt4
# NGOpt8
# NGOptBase
# NaiveIsoEMNA
# NaiveTBPSA
# NelderMead
# NoisyBandit
# NoisyDE
# NoisyDiscreteOnePlusOne
# NoisyOnePlusOne
# NonNSGAIIES
# ORandomSearch
# OScrHammersleySearch
# OnePlusOne
# OptimisticDiscreteOnePlusOne
# OptimisticNoisyOnePlusOne
# PCABO
# PSO
# ParaPortfolio
# PolyCMA
# Portfolio
# PortfolioDiscreteOnePlusOne
# Powell
# PymooNSGA2
# QORandomSearch
# QOScrHammersleySearch
# QrDE
# RCobyla
# RPowell
# RSQP
# RandomSearch
# RandomSearchPlusMiddlePoint
# RealSpacePSO
# RecES
# RecMixES
# RecMutDE
# RecombiningPortfolioDiscreteOnePlusOne
# RecombiningPortfolioOptimisticNoisyDiscreteOnePlusOne
# RescaledCMA
# RotatedTwoPointsDE
# RotationInvariantDE
# SPSA
# SQP
# SQPCMA
# ScrHaltonSearch
# ScrHaltonSearchPlusMiddlePoint
# ScrHammersleySearch
# ScrHammersleySearchPlusMiddlePoint
# Shiwa
# TBPSA
# TripleCMA
# TwoPointsDE
# cGA

# %% [markdown]
# # Your first unconstrained optimisation

# %%
def square(x):
    return sum((x - 0.5) ** 2)

# optimization on x as an array of shape (2,)
optimizer = ng.optimizers.NGOpt(parametrization = 2, budget = 100)
recommendation = optimizer.minimize(square)  # best value
print(recommendation.value)
# >>> [0.49999998 0.50000004]
# Out:
# [0.5        0.49999995]

# %%
dir(recommendation)
# Out:
# ['_LAYER_LEVEL',
#  '__add__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rpow__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '_call_deeper',
#  '_check_frozen',
#  '_constraint_checkers',
#  '_dimension',
#  '_frozen',
#  '_generation',
#  '_get_name',
#  '_internal_get_standardized_data',
#  '_internal_set_standardized_data',
#  '_layer_index',
#  '_layered_del_value',
#  '_layered_get_value',
#  '_layered_mutate',
#  '_layered_recombine',
#  '_layered_sample',
#  '_layered_set_value',
#  '_layers',
#  '_losses',
#  '_meta',
#  '_name',
#  '_new_with_data_layer',
#  '_on_layer_added',
#  '_random_state',
#  '_set_parenthood',
#  '_set_random_state',
#  '_subobjects',
#  '_to_reduced_space',
#  '_value',
#  'add_layer',
#  'args',
#  'bounds',
#  'copy',
#  'descriptors',
#  'dimension',
#  'freeze',
#  'function',
#  'generation',
#  'get_standardized_data',
#  'get_value_hash',
#  'heritage',
#  'integer',
#  'kwargs',
#  'loss',
#  'losses',
#  'mutate',
#  'name',
#  'parameters',
#  'parents_uids',
#  'random_state',
#  'recombine',
#  'register_cheap_constraint',
#  'sample',
#  'satisfies_constraints',
#  'set_bounds',
#  'set_integer_casting',
#  'set_mutation',
#  'set_name',
#  'set_standardized_data',
#  'sigma',
#  'spawn_child',
#  'uid',
#  'value']

# %% [markdown]
# # Your first constrained optimisation

# %% [markdown]
# - “Cheap” means that we do not try to reduce the number of calls to such constraints.
# - We basically repeat mutations until we get a satisfiable point.
# - Let us say that we want to minimize:
# >((x[0]-.5)^2 + (x[1]-.5)^2)
# - under the constraint
# >(x[0] >= 1)

# %%
def square(x):
    return sum((x - 0.5) ** 2)

optimizer = ng.optimizers.NGOpt(parametrization = 2, budget = 100)
# define a constraint on first variable of x:
optimizer.parametrization.register_cheap_constraint(lambda x: x[0] >= 1)

recommendation = optimizer.minimize(square, verbosity = 2)
print("Final value:", recommendation.value)
# >>> [1.00037625, 0.50683314]
# Out:
# Launching 1 jobs with new suggestions
# Updating fitness with value 5.585201021332205
# 99 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 5.585201021332205, count: 1, parameter: Array{(2,)}:[ 1.80181506 -1.47242961]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 4.357677657530252
# 98 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 4.357677657530252, count: 1, parameter: Array{(2,)}:[ 1.46437718 -1.35139254]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.4136244411939989
# 97 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 3.2300195275554304
# 96 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 3.260067031531029
# 95 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 2.3103998485556874
# 94 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 5.922448419503093
# 93 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.9165302911609434
# 92 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 4.81932543515841
# 91 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 4.04498143621014
# 90 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 4.246719154046897
# 89 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 1.9937672989952913
# 88 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 3.1235380810348228
# 87 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 3.496551237025494
# 86 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.4136244411939989, count: 1, parameter: Array{(2,)}:[1.00832898 0.10601257]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2577173466897536
# 85 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 4.039014909999658
# 84 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 2.056605804938333
# 83 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 3.534946515821215
# 82 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 1.2151740560887296
# 81 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.8346412579319789
# 80 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 2.1658627979605534
# 79 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.4929629128586409
# 78 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.5889012177971726
# 77 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.6094951405318231
# 76 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 1.3372446074328947
# 75 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 1.8290233087515704
# 74 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.28249066929334044
# 73 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 1.6014654773971362
# 72 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 1.9276712888252854
# 71 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.6988090493065937
# 70 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 1.0852705842509196
# 69 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 1.9177824647868398
# 68 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 2.823036531819048
# 67 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.44565360182599956
# 66 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 1.3215530760144194
# 65 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.28167430011861655
# 64 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.46954763648632225
# 63 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.6364898991275401
# 62 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.41960378640380985
# 61 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.6904816189512507
# 60 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.5898897900789983
# 59 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.30266547453971976
# 58 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.5405196033297542
# 57 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.4327330956815489
# 56 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.31551324012596027
# 55 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2710624885045143
# 54 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.31711481327418245
# 53 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.28371492957976274
# 52 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.4179386694595254
# 51 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.3671593959929354
# 50 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.28797696937654527
# 49 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.29069678669337357
# 48 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.3422639228534887
# 47 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2577173466897536, count: 1, parameter: Array{(2,)}:[1.00282619 0.56987966]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2575631397484242
# 46 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.3045531591101458
# 45 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.3498879524676125
# 44 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.26611568479661896
# 43 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2920020410753451
# 42 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.37558970603407066
# 41 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2687575145499712
# 40 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2696155686616341
# 39 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.3671087273068346
# 38 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2927034891582156
# 37 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2737177895573299
# 36 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.25862986794642884
# 35 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.34006599782180386
# 34 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2991651204320703
# 33 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.3115899163519545
# 32 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2762243933322894
# 31 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.27868769966593954
# 30 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.27720178769257425
# 29 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2743226622942316
# 28 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.28495604742516245
# 27 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2575631397484242, count: 1, parameter: Array{(2,)}:[1.00672378 0.47181941]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2565290764041153
# 26 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2565290764041153, count: 1, parameter: Array{(2,)}:[1.00216277 0.56604265]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.26026858431312305
# 25 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2565290764041153, count: 1, parameter: Array{(2,)}:[1.00216277 0.56604265]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.27288976062104614
# 24 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2565290764041153, count: 1, parameter: Array{(2,)}:[1.00216277 0.56604265]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.26744019669063296
# 23 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2565290764041153, count: 1, parameter: Array{(2,)}:[1.00216277 0.56604265]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2617115372974177
# 22 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2565290764041153, count: 1, parameter: Array{(2,)}:[1.00216277 0.56604265]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.264945657994561
# 21 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2565290764041153, count: 1, parameter: Array{(2,)}:[1.00216277 0.56604265]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2757214399533214
# 20 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2565290764041153, count: 1, parameter: Array{(2,)}:[1.00216277 0.56604265]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.25646995535425476
# 19 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.25646995535425476, count: 1, parameter: Array{(2,)}:[1.00601568 0.52044709]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2915118149015592
# 18 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.25646995535425476, count: 1, parameter: Array{(2,)}:[1.00601568 0.52044709]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2720806709169572
# 17 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.25646995535425476, count: 1, parameter: Array{(2,)}:[1.00601568 0.52044709]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.26294546320521567
# 16 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.25646995535425476, count: 1, parameter: Array{(2,)}:[1.00601568 0.52044709]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.26437958471171064
# 15 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.25646995535425476, count: 1, parameter: Array{(2,)}:[1.00601568 0.52044709]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.25832373422630084
# 14 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.25646995535425476, count: 1, parameter: Array{(2,)}:[1.00601568 0.52044709]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2549215929831337
# 13 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2549215929831337, count: 1, parameter: Array{(2,)}:[1.00487659 0.5046063 ]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2661649825380564
# 12 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2549215929831337, count: 1, parameter: Array{(2,)}:[1.00487659 0.5046063 ]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.26364045839983485
# 11 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2549215929831337, count: 1, parameter: Array{(2,)}:[1.00487659 0.5046063 ]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.26272932734131993
# 10 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2549215929831337, count: 1, parameter: Array{(2,)}:[1.00487659 0.5046063 ]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.262869187552066
# 9 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2549215929831337, count: 1, parameter: Array{(2,)}:[1.00487659 0.5046063 ]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.25945011029397935
# 8 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2549215929831337, count: 1, parameter: Array{(2,)}:[1.00487659 0.5046063 ]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2514117059717723
# 7 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2514117059717723, count: 1, parameter: Array{(2,)}:[1.00038001 0.53211777]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2690048088094581
# 6 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2514117059717723, count: 1, parameter: Array{(2,)}:[1.00038001 0.53211777]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.258296811023114
# 5 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2514117059717723, count: 1, parameter: Array{(2,)}:[1.00038001 0.53211777]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.25933398517094236
# 4 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2514117059717723, count: 1, parameter: Array{(2,)}:[1.00038001 0.53211777]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2529053259695302
# 3 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2514117059717723, count: 1, parameter: Array{(2,)}:[1.00038001 0.53211777]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2620841873556879
# 2 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2514117059717723, count: 1, parameter: Array{(2,)}:[1.00038001 0.53211777]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.254942116615875
# 1 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2514117059717723, count: 1, parameter: Array{(2,)}:[1.00038001 0.53211777]>
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.25538022112643993
# 0 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.2514117059717723, count: 1, parameter: Array{(2,)}:[1.00038001 0.53211777]>
# Final value: [1.00038001 0.53211777]

# %% [markdown]
# # Multi-objective optimisation

# %% [markdown]
# - According to the official documentation this option is not stable, not robust, not scalable and not optimal.
# - It is unclear to me if this is still the case and further investigation will need to be carried out.

# %%
def multiobjective(x):
    return [np.sum(x ** 2), np.sum((x - 1) ** 2)]

print("Example: ", multiobjective(np.array([1.0, 2.0, 0])))
# >>> Example: [5.0, 2.0]

optimizer = ng.optimizers.CMA(parametrization=3, budget=100)

# for all but DE optimizers, deriving a volume out of the losses,
# it's not strictly necessary but highly advised to provide an
# upper bound reference for the losses (if not provided, such upper
# bound is automatically inferred with the first few "tell")
optimizer.tell(ng.p.MultiobjectiveReference(), [5, 5])
# note that you can provide a Parameter to MultiobjectiveReference,
# which will be passed to the optimizer

optimizer.minimize(multiobjective, verbosity = 0)

# The function embeds its Pareto-front:
print("Pareto front:")
for param in sorted(optimizer.pareto_front(), key=lambda p: p.losses[0]):
    print(f"{param} with losses {param.losses}")

# >>> Array{(3,)}:[0. 0. 0.] with loss [0. 3.]
#     Array{(3,)}:[0.39480968 0.98105712 0.55785803] with loss [1.42955333 0.56210368]
#     Array{(3,)}:[1.09901515 0.97673712 0.97153943] with loss [3.10573857 0.01115516]

# It can also provide subsets:
print("Random subset:", optimizer.pareto_front(2, subset="random"))
print("Loss-covering subset:", optimizer.pareto_front(2, subset="loss-covering"))
print("Domain-covering subset:", optimizer.pareto_front(2, subset="domain-covering"))
print("EPS subset:", optimizer.pareto_front(2, subset="EPS"))
# Out:
# Example:  [5.0, 2.0]
# Pareto front:
# Array{(3,)}:[0.03229814 0.05926466 0.12404622] with losses [0.01994293 2.58872491]
# Array{(3,)}:[0.13930313 0.09500046 0.01775613] with losses [0.02874573 2.5246263 ]
# Array{(3,)}:[0.23857447 0.09909974 0.07771459] with losses [0.07277809 2.2420005 ]
# Array{(3,)}:[0.04546177 0.12369125 0.25323448] with losses [0.081494 2.236719]
# Array{(3,)}:[0.05429401 0.25665873 0.21388397] with losses [0.1145679  2.06489447]
# Array{(3,)}:[0.24503426 0.31927256 0.0260395 ] with losses [0.16265481 1.98196218]
# Array{(3,)}:[0.33750681 0.24970508 0.19711778] with losses [0.2151189  1.64645954]
# Array{(3,)}:[0.15928702 0.47201215 0.21161361] with losses [0.29294814 1.6071226 ]
# Array{(3,)}:[0.67776098 0.37213942 0.12104515] with losses [0.61249962 1.27060851]
# Array{(3,)}:[0.43094016 0.34455746 0.60361598] with losses [0.66878151 0.91055431]
# Array{(3,)}:[0.63523424 0.59251202 0.23971277] with losses [0.81205524 0.87713719]
# Array{(3,)}:[0.9888735  0.67214548 0.1836611 ] with losses [1.46338175 0.77402159]
# Array{(3,)}:[0.71410415 0.9169426  0.34530609] with losses [1.46996476 0.51725908]
# Array{(3,)}:[0.88111006 0.37642843 0.8521555 ] with losses [1.64422229 0.42483431]
# Array{(3,)}:[1.095123   0.67906573 0.4993963 ] with losses [1.9098213  0.36265125]
# Array{(3,)}:[0.57270116 1.27425651 0.67722343] with losses [2.41034785 0.36198565]
# Array{(3,)}:[1.11228788 1.10888865 0.52176728] with losses [2.73905945 0.25317184]
# Array{(3,)}:[0.81172886 1.21972865 1.1596872 ] with losses [3.49151614 0.10922671]
# Random subset: [Array{(3,)}:[0.81172886 1.21972865 1.1596872 ], Array{(3,)}:[1.095123   0.67906573 0.4993963 ]]
# Loss-covering subset: [Array{(3,)}:[0.88111006 0.37642843 0.8521555 ], Array{(3,)}:[0.24503426 0.31927256 0.0260395 ]]
# Domain-covering subset: [Array{(3,)}:[0.71410415 0.9169426  0.34530609], Array{(3,)}:[0.33750681 0.24970508 0.19711778]]
# EPS subset: [Array{(3,)}:[0.03229814 0.05926466 0.12404622], Array{(3,)}:[0.24503426 0.31927256 0.0260395 ]]

# %% [markdown]
# # Bounded continous variables and discrete variables

# %%
def fake_training(learning_rate: float, batch_size: int, architecture: str) -> float:
    # optimal for learning_rate=0.2, batch_size=4, architecture="conv"
    return (learning_rate - 0.2)**2 + (batch_size - 4)**2 + (0 if architecture == "conv" else 10)

# Instrumentation class is used for functions with multiple inputs
# (positional and/or keywords)
parametrization = ng.p.Instrumentation(
    # a log-distributed scalar between 0.001 and 1.0
    learning_rate=ng.p.Log(lower=0.001, upper=1.0),
    # an integer from 1 to 12
    batch_size=ng.p.Scalar(lower=1, upper=12).set_integer_casting(),
    # either "conv" or "fc"
    architecture=ng.p.Choice(["conv", "fc"])
)

optimizer = ng.optimizers.NGO(parametrization=parametrization, budget=100)
recommendation = optimizer.minimize(fake_training)

# show the recommended keyword arguments of the function
print(recommendation.kwargs)
# Out:
# {'learning_rate': 0.16074961067847227, 'batch_size': 4, 'architecture': 'conv'}

# %% [markdown]
# # References

# %% [markdown]
# - https://facebookresearch.github.io/nevergrad/optimization.html
# - https://reposhub.com/python/deep-learning/facebookresearch-nevergrad.html

# %% [markdown]
# # Conclusions

# %% [markdown]
# - Still very little documentation online.
# - It seems to have an edge for truly gradient-free multi-objective problems.
